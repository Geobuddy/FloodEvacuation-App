# %% [markdown]
# <h1> <center> FLood Evacuation App </center> </h1>
# <h4> <center> This application will help you quickest route to the highest point of land within a 5km radius  </center></h4>
# <h4> <center> Please run the cell below by selecting it and then clicking run on the top of the page or alternative pressing SHIFT + ENTER. </center> </h4>

# %%
# %run app.ipynb
# Out:
# <h2><center>The point you entered is at 450000, 85000</center></h2>
# <h2><center>Your destination is at 445027, 85512</center></h2>
